# %% [markdown]
# # Emirates Airways Reviews Project

# %% [markdown]
# ### import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('Emirates Airways Reviews.csv')

# %%
data.head()
# Out:
#                                        Title    Date Published         Status  \
# 0                "upgrade to business class"  12th August 2024  Trip Verified
# 1            "14 hour horrendous experience"  11th August 2024  Trip Verified
# 2  "not welcome and passengers are a burden"    29th July 2024   Not Verified
# 3     "should be considered among the worst"    18th July 2024  Trip Verified
# 4                  “services are very great”    13th July 2024   Not Verified
#
#          Aircraft     Travel Type    Travel Class  \
# 0      Boeing 777    Solo Leisure  Business Class
# 1             NaN  Couple Leisure   Economy Class
# 2  Boeing 777-300    Solo Leisure   Economy Class
# 3            A380        Business   Economy Class
# 4            A380  Family Leisure   Economy Class
#
#                                Route   Date Flown  Seating Comfort  \
# 0                    Dubai to Lisbon  August 2024              5.0
# 1          Delhi to Boston via Dubai  August 2024              1.0
# 2      Amsterdam to Phuket via Dubai    June 2024              2.0
# 3  Manchester to Singapore via Dubai    July 2024              1.0
# 4               Bangkok to Hong Kong  August 2023              5.0
#
#    Staff Service  Food Quality  Entertainment  WiFi  Ground Service  \
# 0            5.0           5.0            5.0   5.0             5.0
# 1            1.0           3.0            3.0   2.0             3.0
# 2            1.0           4.0            2.0   3.0             3.0
# 3            1.0           2.0            NaN   NaN             1.0
# 4            5.0           5.0            5.0   4.0             5.0
#
#    Value for Money Recommended  Overall Rating  \
# 0                5         yes              10
# 1                2          no               4
# 2                2          no               5
# 3                1          no               1
# 4                5         yes              10
#
#                                               Review               Country
# 0     I flew a return trip DXB-LIS-DXB I used my ...  United Arab Emirates
# 1     We were 2 people travelling together and on...                 India
# 2     First time flying Emirates, was expecting a...           Netherlands
# 3    Ground Staff and Service Failures on Flight ...             Singapore
# 4    The staff are friendly and the seat is comfo...             Hong Kong

# %% [markdown]
# ## Data Preprocessing
# understnding the Data structure

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1540 non-null   object
#  1   Date Published   1540 non-null   object
#  2   Status           1398 non-null   object
#  3   Aircraft         1037 non-null   object
#  4   Travel Type      1540 non-null   object
#  5   Travel Class     1540 non-null   object
#  6   Route            1538 non-null   object
#  7   Date Flown       1540 non-null   object
#  8   Seating Comfort  1477 non-null   float64
#  9   Staff Service    1476 non-null   float64
#  10  Food Quality     1418 non-null   float64
#  11  Entertainment    1380 non-null   float64
#  12  WiFi             934 non-null    float64
#  13  Ground Service   1501 non-null   float64
#  14  Value for Money  1540 non-null   int64
#  15  Recommended      1540 non-null   object
#  16  Overall Rating   1540 non-null   int64
#  17  Review           1540 non-null   object
#  18  Country          1540 non-null   object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 228.7+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1540 non-null   object
#  1   Date Published   1540 non-null   object
#  2   Status           1398 non-null   object
#  3   Aircraft         1037 non-null   object
#  4   Travel Type      1540 non-null   object
#  5   Travel Class     1540 non-null   object
#  6   Route            1538 non-null   object
#  7   Date Flown       1540 non-null   object
#  8   Seating Comfort  1477 non-null   float64
#  9   Staff Service    1476 non-null   float64
#  10  Food Quality     1418 non-null   float64
#  11  Entertainment    1380 non-null   float64
#  12  WiFi             934 non-null    float64
#  13  Ground Service   1501 non-null   float64
#  14  Value for Money  1540 non-null   int64
#  15  Recommended      1540 non-null   object
#  16  Overall Rating   1540 non-null   int64
#  17  Review           1540 non-null   object
#  18  Country          1540 non-null   object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 228.7+ KB

# %%
data.shape
# Out:
# (1540, 19)

# %%
data.dtypes
# Out:
# Title               object
# Date Published      object
# Status              object
# Aircraft            object
# Travel Type         object
# Travel Class        object
# Route               object
# Date Flown          object
# Seating Comfort    float64
# Staff Service      float64
# Food Quality       float64
# Entertainment      float64
# WiFi               float64
# Ground Service     float64
# Value for Money      int64
# Recommended         object
# Overall Rating       int64
# Review              object
# Country             object
# dtype: object

# %%
data.describe()
# Out:
#        Seating Comfort  Staff Service  Food Quality  Entertainment  \
# count      1477.000000    1476.000000   1418.000000    1380.000000
# mean          3.223426       2.977642      3.000000       3.704348
# std           1.401284       1.592836      1.476707       1.376108
# min           1.000000       1.000000      1.000000       1.000000
# 25%           2.000000       1.000000      2.000000       3.000000
# 50%           3.000000       3.000000      3.000000       4.000000
# 75%           4.000000       5.000000      4.000000       5.000000
# max           5.000000       5.000000      5.000000       5.000000
#
#              WiFi  Ground Service  Value for Money  Overall Rating
# count  934.000000      1501.00000      1540.000000     1540.000000
# mean     2.751606         2.85010         2.819481        4.814286
# std      1.478815         1.59233         1.534489        3.331275
# min      1.000000         1.00000         1.000000        1.000000
# 25%      1.000000         1.00000         1.000000        2.000000
# 50%      3.000000         3.00000         3.000000        4.000000
# 75%      4.000000         4.00000         4.000000        8.000000
# max      5.000000         5.00000         5.000000       10.000000

# %%
data.isnull().sum()
# Out:
# Title                0
# Date Published       0
# Status             142
# Aircraft           503
# Travel Type          0
# Travel Class         0
# Route                2
# Date Flown           0
# Seating Comfort     63
# Staff Service       64
# Food Quality       122
# Entertainment      160
# WiFi               606
# Ground Service      39
# Value for Money      0
# Recommended          0
# Overall Rating       0
# Review               0
# Country              0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Title', 'Date Published', 'Status', 'Aircraft', 'Travel Type',
#        'Travel Class', 'Route', 'Date Flown', 'Seating Comfort',
#        'Staff Service', 'Food Quality', 'Entertainment', 'WiFi',
#        'Ground Service', 'Value for Money', 'Recommended', 'Overall Rating',
#        'Review', 'Country'],
#       dtype='object')

# %% [markdown]
# ## Handling Missing Values

# %%
data['Aircraft'].fillna('unknown',inplace=True)
data['Status'].fillna('Not Verified',inplace=True)
data['Route'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Qcc\AppData\Local\Temp\ipykernel_22620\4014985746.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Aircraft'].fillna('unknown',inplace=True)
# C:\Users\Qcc\AppData\Local\Temp\ipykernel_22620\4014985746.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Status'].fillna('Not Verified',inplace=True)
# C:\Users\Qcc\AppData\Local\Temp\ipykernel_22620\4014985746.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Route'].fillna('Unknown',inplace=True)

# %%
data['Date Flown'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Qcc\AppData\Local\Temp\ipykernel_22620\1647392538.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Date Flown'].fillna('Unknown',inplace=True)

# %%
# numerical columns
numerical_cols=['Seating Comfort',
       'Staff Service', 'Food Quality', 'Entertainment', 'WiFi',
       'Ground Service',]
for col in numerical_cols:
    data[col].fillna(data[col].median(),inplace=True)
# Out:
# C:\Users\Qcc\AppData\Local\Temp\ipykernel_22620\961317791.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].median(),inplace=True)

# %%
data.isna().sum()
# Out:
# Title              0
# Date Published     0
# Status             0
# Aircraft           0
# Travel Type        0
# Travel Class       0
# Route              0
# Date Flown         0
# Seating Comfort    0
# Staff Service      0
# Food Quality       0
# Entertainment      0
# WiFi               0
# Ground Service     0
# Value for Money    0
# Recommended        0
# Overall Rating     0
# Review             0
# Country            0
# dtype: int64

# %% [markdown]
# ## Data type Conversion

# %%
data['Date Published']=pd.to_datetime(data['Date Published'],errors='coerce')

# %%
# convert 'Recoomended' to boolean
data['Recommended']=data['Recommended'].map({'yes':True, 'no': False})

# %%
# Ensure numerical column are float
for col in numerical_cols + ['Overall Rating']:
    data[col] =data[col].astype(float)

# %%
data.dtypes
# Out:
# Title                      object
# Date Published     datetime64[ns]
# Status                     object
# Aircraft                   object
# Travel Type                object
# Travel Class               object
# Route                      object
# Date Flown                 object
# Seating Comfort           float64
# Staff Service             float64
# Food Quality              float64
# Entertainment             float64
# WiFi                      float64
# Ground Service            float64
# Value for Money             int64
# Recommended                  bool
# Overall Rating            float64
# Review                     object
# Country                    object
# dtype: object

# %%
data['Value for Money']=data['Value for Money'].astype(float)

# %% [markdown]
# ## Cleaning text Data
# -Clean text Cloumns

# %%
data['Review']=data['Review'].str.strip()
data['Title']=data['Title'].str.strip()

# %% [markdown]
# ### Remove any non ASCII characters

# %%
data['Review']=data['Review'].str.encode('ascii','ignore').str.decode('ascii')

# %% [markdown]
# ### Handling Duplicates

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
data[numerical_cols +['Overall Rating']].describe()
# Out:
#        Seating Comfort  Staff Service  Food Quality  Entertainment  \
# count      1540.000000    1540.000000   1540.000000    1540.000000
# mean          3.214286       2.978571      3.000000       3.735065
# std           1.373017       1.559371      1.416968       1.305734
# min           1.000000       1.000000      1.000000       1.000000
# 25%           2.000000       1.000000      2.000000       3.000000
# 50%           3.000000       3.000000      3.000000       4.000000
# 75%           4.000000       5.000000      4.000000       5.000000
# max           5.000000       5.000000      5.000000       5.000000
#
#               WiFi  Ground Service  Overall Rating
# count  1540.000000     1540.000000     1540.000000
# mean      2.849351        2.853896        4.814286
# std       1.157805        1.572201        3.331275
# min       1.000000        1.000000        1.000000
# 25%       2.000000        1.000000        2.000000
# 50%       3.000000        3.000000        4.000000
# 75%       3.000000        4.000000        8.000000
# max       5.000000        5.000000       10.000000

# %% [markdown]
# ### Distribution of Ratings

# %%
# plot histograms for numerical ratings
plt.figure(figsize=(15,10))
for i, col in enumerate(numerical_cols+['Overall Rating'],1):
    plt.subplot(3,3,i)
    sns.histplot(data[col],bins=10, kde=True)
    plt.title(f'Disribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Correlation Analysis

# %%
# Correlation atrix
corr=data[numerical_cols + ['Overall Rating']].corr()

# %%
# plat heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap='coolwarm' , vmin=-1,vmax=1)
plt.title('Correlation Matrix of Ratings')
plt.show()

# %% [markdown]
# ### Categorial Analysis

# %%
# Travel class
plt.figure(figsize=(8,5))
sns.countplot(data=data,x='Travel Class')
plt.title("Distribution of Travel Class")
plt.xlabel("Travel Class ")
plt.ylabel('Count')
plt.show()

# %%
# Countplot for recomended
plt.figure(figsize=(8,5))
sns.countplot(data=data,x='Recommended')
plt.title('Distribution of Recommende')
plt.xlabel('Recommanded')
plt.ylabel('Count')
plt.show()

# %%
# Average overall rating of travel class
plt.figure(figsize=(8,5))
sns.boxenplot(data=data,x='Travel Class',y='Overall Rating')
plt.title('Overall Rating by Travel Class')
plt.xlabel('Travel Class')
plt.ylabel('Overall Rating')
plt.show()

# %% [markdown]
# ## Time-Based Analyasis

# %%
# data Published must b in Datetime formate
data['Year']=data['Date Published'].dt.year
data['Month']=data['Date Published'].dt.month

# %%
# Average Overall rating by year
plt.figure(figsize=(10,6))
sns.lineplot(data=data.groupby('Year')['Overall Rating'].mean().reset_index(),x='Year',y='Overall Rating')
plt.title('Average Overall Rating by year')
plt.xlabel('Year')
plt.ylabel('Average Overall Rating')
plt.show()

# %% [markdown]
# ## Country based analysis

# %%
top_countries=data['Country'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_countries.values,y=top_countries.index)
plt.title('Top 10 Countries by Review count')
plt.xlabel('Number of Reviews')
plt.ylabel('Country')
plt.show()

# %%
# Average Overall Rating by Country
country_rating=data.groupby('Country')['Overall Rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=country_rating.values,y=country_rating.index)
plt.title('Top 10 Countries by Average Overaall Rating')
plt.xlabel('Average Overall Rating')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Saving the Processed Data

# %%
data.to_csv('Emirates_Airways_Reviews+processed.csv',index=False)
print('Your')
